# %% [markdown]
# # This file contains showcase of Kirkpatrick's point location algorithm

# %%
import json
import os
from  point_location.visual_kirkpatrick.visual_kirkpatrick import VisualKirkpatrick
from point_location.visual_kirkpatrick.showcase_utils import pick_point, create_planar_subdivision
import matplotlib.pyplot as plt

# %%
test_no = 4
test_dir = "test_input"
test_name = f"test{test_no}.json"

with open(os.path.join(test_dir, test_name), 'r') as file:
    data = json.load(file)

vertices = data["vertices"]
segments = data["segments"]

# %%
# %matplotlib inline
plt.close("all")
kirkpatrick = VisualKirkpatrick(vertices, segments)
kirkpatrick.visual_preprocessing()

# %%
points_to_locate = data["points_A"]
points_iter = iter(points_to_locate)

# %%
result = kirkpatrick.visual_locate_point(next(points_iter))

# %%
# %matplotlib ipympl
points, edges = create_planar_subdivision()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline
plt.close("all")
kirkpatrick = VisualKirkpatrick(points, edges)
kirkpatrick.visual_preprocessing()
# Out:
# /home/wiktor/university/sem3/kirkpatrick_point_location/bit_algo_vis_tool/visualizer/plot/plot.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()

# %%
# %matplotlib ipympl
point = pick_point(kirkpatrick)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline
plt.close("all")
result = kirkpatrick.visual_locate_point(point[0])
